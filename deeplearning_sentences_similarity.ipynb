# %% [markdown]
# <a href="https://colab.research.google.com/github/iniadittt/model-sentences/blob/main/deeplearning_sentences_similarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install sentence_transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 101.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 20.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 129.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.8 MB/s eta 0:00:00
# ...
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=64759677ef712d2a0f6ccb9a836b6af29efce9184939272578b4035cb3dc97bb
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# ...

# %%
import tensorflow as tf
from sentence_transformers import SentenceTransformer, util
from sklearn.metrics.pairwise import cosine_similarity

# %%
model = SentenceTransformer('paraphrase-albert-small-v2')

# %%
data = """Pantun adalah salah satu jenis puisi lama yang sangat luas dikenal di Asia tenggara.
Pantun memiliki sajak ABAB. Dalam bahasa Sunda pantun disebut paparikan dan dalam bahasa Batak,
pantun dikenal dengan sebutan umpasa."""
answer = """Pantun adalah salah satu jenis puisi lama yang sangat luas dikenal di Nusantara."""

sentences1 = [data]
sentences2 = [answer]

# %%
# Menghasilkan embedding untuk kalimat-kalimat
embeddings1 = model.encode(sentences1, convert_to_tensor=True)
embeddings2 = model.encode(sentences2, convert_to_tensor=True)

# %%
# Menghitung kemiripan antara embedding kalimat menggunakan cosine similarity
# similarity_scores = tf.reduce_sum(tf.multiply(tf.nn.l2_normalize(embeddings1, axis=1), tf.nn.l2_normalize(embeddings2, axis=1)), axis=1)

# %%
cosine_scores = util.pytorch_cos_sim(embeddings1, embeddings2)
similarity_scores = tf.reduce_sum(tf.multiply(tf.nn.l2_normalize(embeddings1, axis=1),
                                            tf.nn.l2_normalize(embeddings2, axis=1)),
                                            axis=1)
similarity = cosine_similarity(embeddings1.numpy(), embeddings2.numpy())
result = [cosine_scores[0][0].item(), similarity_scores[0].numpy(), similarity[0][0]]
result = max(result)

# %%
print('Similarity Score: ', result)
# Out:
# Similarity Score:  0.7480713
